# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-Visualization-in-Python" data-toc-modified-id="Data-Visualization-in-Python-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Visualization in Python</a></span><ul class="toc-item"><li><span><a href="#Using-matplotlib" data-toc-modified-id="Using-matplotlib-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Using matplotlib</a></span><ul class="toc-item"><li><span><a href="#Scatter-plots" data-toc-modified-id="Scatter-plots-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Scatter plots</a></span></li><li><span><a href="#Bar-plots" data-toc-modified-id="Bar-plots-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Bar plots</a></span></li><li><span><a href="#Histograms" data-toc-modified-id="Histograms-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Histograms</a></span></li><li><span><a href="#Box-plots" data-toc-modified-id="Box-plots-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>Box plots</a></span></li><li><span><a href="#Line-charts" data-toc-modified-id="Line-charts-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>Line charts</a></span></li></ul></li><li><span><a href="#Using-seaborn" data-toc-modified-id="Using-seaborn-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Using seaborn</a></span><ul class="toc-item"><li><span><a href="#Scatter-plots" data-toc-modified-id="Scatter-plots-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Scatter plots</a></span></li><li><span><a href="#Bar-plots" data-toc-modified-id="Bar-plots-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Bar plots</a></span></li><li><span><a href="#Histograms" data-toc-modified-id="Histograms-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Histograms</a></span></li><li><span><a href="#Line-charts" data-toc-modified-id="Line-charts-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Line charts</a></span></li></ul></li><li><span><a href="#Using-plotly" data-toc-modified-id="Using-plotly-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Using plotly</a></span><ul class="toc-item"><li><span><a href="#Choropleth-maps" data-toc-modified-id="Choropleth-maps-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Choropleth maps</a></span></li><li><span><a href="#Bubble-maps" data-toc-modified-id="Bubble-maps-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Bubble maps</a></span></li></ul></li><li><span><a href="#Sample-exercise" data-toc-modified-id="Sample-exercise-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Sample exercise</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Data Visualization in Python

# %%
# Import libraries
import csv
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import seaborn as sns

# %%
# Load the data
data = pd.read_csv(
    'micro_world.csv',
    engine='python'
    )

# %% [markdown]
# ## Using matplotlib

# %% [markdown]
# ### Scatter plots
#
# Scatter plots are one of the most essential plots in data science. Before building regression models, we usually run a scatter plot on our data to inspect possible correlations.

# %% [markdown]
# Since we don't have enough continuous data in our dataset, we will create synthetic data.

# %%
# Create synthetic data
monthly_credit_transactions = [
    3,
    5,
    4,
    5,
    7,
    8,
    4,
    0,
    1,
    4
]
monthly_income = [
    20000,
    40000,
    34000,
    31000,
    60000,
    70000,
    55000,
    10000,
    15000,
    55000
]

# %% [markdown]
# At this point, let us assume that the monthly income is the independent variable while the monthly number of credit transactions is the dependent variable.

# %%
# Assign to variables
x = monthly_income
y = monthly_credit_transactions

# %%
# Apply scatterplot
plt.scatter(x, y)

plt.show()

# %% [markdown]
# We call plt.show() so matplotlib will know that we wanted to display the figure we created using plt.scatter().
#
# Now, let's stylize our scatterplot.

# %%
# Apply scatterplot
plt.scatter(
    x, 
    y
)

# Set title
plt.title('Plot of transactions vs income')

# Set labels
plt.xlabel('Number of credit transactions')
plt.ylabel('Monthly Income (in pesos)')
# Out:
# Text(0, 0.5, 'Monthly Income (in pesos)')

# %% [markdown]
# **Too small!** Let's make this bigger.

# %%
# Set figure size
plt.figure(figsize=(6,3), dpi=200)

# Run scatter plot
plt.scatter(
    x, 
    y
)

# Set title
plt.title('Plot of transactions vs income')

# Set labels
plt.xlabel('Number of credit transactions')
plt.ylabel('Monthly Income (in pesos)')

# Show figure
plt.show()

# %% [markdown]
# What if I want to change the limit of the x and y-axes?

# %%
# Set figure size
plt.figure(figsize=(6,3)  , dpi=200)

# Run scatter plot
plt.scatter(
    x, 
    y
)

# Set title
plt.title('Plot of transactions vs income')

# Set labels
plt.xlabel('Number of credit transactions')
plt.ylabel('Monthly Income (in pesos)')

# Set limit of x-axis
plt.xlim([0,100000])

# Set limit of y-axis
plt.ylim([0,10])

# Show figure
plt.show()

# %% [markdown]
# ### Bar plots

# %% [markdown]
# To create our bar plots, let's compute the percentage of population with debit card per country.

# %%
# Create another column for debit card ownership
data['has_debit_card'] = data['fin2'].apply(
    lambda x: 1 if x == 1 else 0
    )

# Group the data and apply aggregations
grouped_data = data.groupby(['economy', 'economycode', 'regionwb']).agg(
    total_debit_card_owners=('has_debit_card', 'sum'),
    total_population=('wpid_random', 'count')
).reset_index()

# Compute debit card ownership in %
grouped_data['% of population with debit card'] = grouped_data['total_debit_card_owners']*100.0/grouped_data['total_population']

# Sort and pick top 10 countries in terms of % debit card ownership
top_10 = grouped_data.sort_values('% of population with debit card', ascending=False).head(10).reset_index(drop=True)

# Show data
top_10
# Out:
#           economy economycode           regionwb  total_debit_card_owners  \
# 0     Netherlands         NLD  High income: OECD                      987
# 1          Norway         NOR  High income: OECD                      986
# 2          Sweden         SWE  High income: OECD                      982
# 3         Finland         FIN  High income: OECD                      982
# 4         Denmark         DNK  High income: OECD                      975
# 5     New Zealand         NZL  High income: OECD                      968
# 6         Belgium         BEL  High income: OECD                      960
# 7          Canada         CAN  High income: OECD                      958
# 8        Slovenia         SVN  High income: OECD                      949
# 9  United Kingdom         GBR  High income: OECD                      932
#
#    total_population  % of population with debit card
# 0              1000                        98.700000
# 1              1000                        98.600000
# 2              1000                        98.200000
# 3              1000                        98.200000
# 4              1000                        97.500000
# 5              1000                        96.800000
# 6              1001                        95.904096
# 7              1003                        95.513460
# 8              1000                        94.900000
# 9              1000                        93.200000

# %%
# Run bar plot
plt.bar(
    top_10['economy'],
    top_10['% of population with debit card']
)

# Show figure
plt.show()

# %% [markdown]
# **Looks awful.** 😩😩😩
#
# Let's apply some styling! We will repeat what we did in scatter plot except we will also rotate the tick labels of x axis so they are more readable.

# %%
# Set figure size
plt.figure(figsize=(6,3)  , dpi=200)

# Run bar plot
plt.bar(
    top_10['economy'],
    top_10['% of population with debit card']
)

# Set title
plt.title('Top 10 Countries in terms of % Population with Debit Card')

# Set labels
plt.xlabel('Countries')
plt.ylabel('% Population with Debit Card')

# Rotate x labels
plt.xticks(rotation=45)

# Show figure
plt.show()

# %% [markdown]
# To make this better, let's run a horizontal bar plot instead of vertical bar plot.

# %%
# Set figure size
plt.figure(figsize=(6,3)  , dpi=200)

# Run bar plot
plt.barh(
    top_10['economy'],
    top_10['% of population with debit card']
)

# Set title
plt.title('Top 10 Countries in terms of % Population with Debit Card')

# Set labels
plt.ylabel('% Population with Debit Card')
plt.ylabel('Countries')

# Show figure
plt.show()

# %% [markdown]
# ### Histograms
# Histograms are useful in visualizing distributions.
#
# Let's try to plot the age profile of all respondents in the Global Findex 2017 dataset.

# %%
# Run histogram
plt.hist(
    data['age']
)

# Show figure
plt.show()

# %% [markdown]
# Let's stylize our plot!

# %%
# Set figure size
plt.figure(figsize=(6,3)  , dpi=200)

# Run histogram plot
plt.hist(
  data['age'],
  bins=20
)

# Set title
plt.title('Age Profile of Global Findex 2017 Respondets')

# Set labels
plt.xlabel('Age')
plt.ylabel('Frequency')

# Show figure
plt.show()

# %% [markdown]
# ### Box plots
# Box plots, like histograms, are perfect for visualizing distributions.
#
# Here's an anatomy of a box plot:
# ![image.png](data:image/png;base64,...)

# %%
# Run box plot on age
plt.boxplot(data['age'].dropna())
 
# Show figure
plt.show()

# %% [markdown]
# We use .dropna() to remove the nulls in the age column. If we did not do this, plt.boxplot() will not display anything.

# %% [markdown]
# ### Line charts
#
# Line charts are very useful in tracking trends like time-series data.

# %%
# Create synthetic data
months = range(1,13)
credit_transactions = [
    1,
    2,
    3,
    4,
    5,
    4,
    4,
    3,
    2,
    3,
    5,
    10
]

# %%
# Run line chart
plt.plot(
    months,
    credit_transactions
)

# Show figure
plt.show()

# %% [markdown]
# Let's stylize the data!

# %%
# Set figure size
plt.figure(figsize=(6,3)  , dpi=200)

# Run line chart
plt.plot(
  months,
  credit_transactions
)

# Set title
plt.title('Monthly Credit Transactions')

# Set labels
plt.xlabel('Month')
plt.ylabel('Number of Credit Transactions')

# Show figure
plt.show()

# %% [markdown]
# ## Using seaborn

# %% [markdown]
# ### Scatter plots

# %%
# Set figure size
plt.figure(figsize=(6,3)  , dpi=200)

# Apply scatter plot
sns.scatterplot(
    x, 
    y
)

# Set title
plt.title('Plot of transactions vs income')

# Set labels
plt.xlabel('Number of credit transactions')
plt.ylabel('Monthly Income (in pesos)')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# Text(0, 0.5, 'Monthly Income (in pesos)')

# %% [markdown]
# ### Bar plots

# %%
# Set figure size
plt.figure(figsize=(6,3)  , dpi=200)

# Run bar plot
sns.barplot(
    top_10['economy'],
    top_10['% of population with debit card'],
    color='g'
)

# Set title
plt.title('Top 10 Countries in terms of % Population with Debit Card')

# Set labels
plt.xlabel('Countries')
plt.ylabel('% Population with Debit Card')

# Rotate x labels
plt.xticks(rotation=45)

# Show figure
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
# Set figure size
plt.figure(figsize=(6,3)  , dpi=200)

# Run bar plot
sns.barplot(
    top_10['% of population with debit card'],
    top_10['economy'],
    color='g'
)

# Set title
plt.title('Top 10 Countries in terms of % Population with Debit Card')

# Set labels
plt.ylabel('% Population with Debit Card')
plt.ylabel('Countries')

# Show figure
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# ### Histograms

# %% [markdown]
# Here, let's try to create a histogram of age of Netherlands and Philippines.

# %%
# Query records from Netherlands or Philippines
df = data[
    (data['economy'] == 'Philippines') | (data['economy'] == 'Netherlands' )
]

# %%
# Set figure size
plt.figure(figsize=(6,3)  , dpi=200)

# Run histogram plot
sns.histplot(
    data=df, 
    x="age", 
    hue="economy"
    )

# Set title
plt.title(
    'Age Profile of Global Findex 2017 Respondets in Philippines and Netherlands'
    )

# Set labels
plt.xlabel('Age')
plt.ylabel('Frequency')

# Show figure
plt.show()

# %%
# Run box plot on age
sns.boxplot(
    x="economy", 
    y="age", 
    data=df
)
 
# Show figure
plt.show()

# %% [markdown]
# ### Line charts

# %%
# Set figure size
plt.figure(figsize=(6,3)  , dpi=200)

# Run line chart
sns.lineplot(
  months,
  credit_transactions
)

# Set title
plt.title('Monthly Credit Transactions')

# Set labels
plt.xlabel('Month')
plt.ylabel('Number of Credit Transactions')

# Show figure
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# ## Using plotly

# %% [markdown]
# Plotly is similar to matplotlib and seaborn but it also allows for plotting geospatial data.
#
# One example of it is the choropleth map. Let's use the data containing % of population with debit card for this one.

# %% [markdown]
# ### Choropleth maps

# %%
# Show data
grouped_data
# Out:
#                 economy economycode  \
# 0           Afghanistan         AFG
# 1               Albania         ALB
# 2               Algeria         DZA
# 3             Argentina         ARG
# 4               Armenia         ARM
# ..                  ...         ...
# 138       Venezuela, RB         VEN
# 139             Vietnam         VNM
# 140  West Bank and Gaza         PSE
# 141              Zambia         ZMB
# 142            Zimbabwe         ZWE
#
#                                               regionwb  \
# 0                                           South Asia
# 1        Europe & Central Asia (excluding high income)
# 2    Middle East & North Africa (excluding high inc...
# 3    Latin America & Caribbean (excluding high income)
# 4        Europe & Central Asia (excluding high income)
# ..                                                 ...
# 138  Latin America & Caribbean (excluding high income)
# 139        East Asia & Pacific (excluding high income)
# 140  Middle East & North Africa (excluding high inc...
# 141         Sub-Saharan Africa (excluding high income)
# 142         Sub-Saharan Africa (excluding high income)
#
#      total_debit_card_owners  total_population  \
# 0                         28              1000
# 1                        278              1000
# 2                        247              1016
# 3                        462              1000
# 4                        264              1000
# ..                       ...               ...
# 138                      685              1000
# 139                      287              1002
# 140                      189              1000
# 141                      232              1000
# 142                      249              1000
#
#      % of population with debit card
# 0                           2.800000
# 1                          27.800000
# 2                          24.311024
# 3                          46.200000
# 4                          26.400000
# ..                               ...
# 138                        68.500000
# 139                        28.642715
# 140                        18.900000
# 141                        23.200000
# 142                        24.900000
#
# [143 rows x 6 columns]

# %%
# Build the choropleth map
fig = px.choropleth(
    grouped_data, 
    locations="economycode",
    color="% of population with debit card",
    hover_name="economy",
    color_continuous_scale='viridis'
)

# Show the map
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="145a9c5f-2646-478e-8984-9177adb867e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("145a9c5f-2646-478e-8984-9177adb867e0")) {                    Plotly.newPlot(                        "145a9c5f-2646-478e-8984-9177adb867e0",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>economycode=%{location}<br>% of population with debit card=%{z}<extra></extra>","hovertext":["Afghanistan","Albania","Algeria","Argentina","Armenia","Australia","Austria","Azerbaijan","Bahrain","Bangladesh","Belarus","Belgium","Benin","Bolivia","Bosnia and Herzegovina","Botswana","Brazil","Bulgaria","Burkina Faso","Cambodia","Cameroon","Canada","Central African Republic","Chad","Chile","China","Colombia","Congo, Dem. Rep.","Congo, Rep.","Costa Rica","Cote d'Ivoire","Croatia","Cyprus","Czech Republic","Denmark","Dominican Republic","Ecuador","Egypt, Arab Rep.","El Salvador","Estonia","Ethiopia","Finland","France","Gabon","Georgia","Germany","Ghana","Greece","Guatemala","Guinea","Haiti","Honduras","Hong Kong SAR, China","Hungary","India","Indonesia","Iran, Islamic Rep.","Iraq","Ireland","Israel","Italy","Japan","Jordan","Kazakhstan","Kenya","Korea, Rep.","Kosovo","Kuwait","Kyrgyz Republic","Lao PDR","Latvia","Lebanon","Lesotho","Liberia","Libya","Lithuania","Luxembourg","Macedonia, FYR","Madagascar","Malawi","Malaysia","Mali","Malta","Mauritania","Mauritius","Mexico","Moldova","Mongolia","Montenegro","Morocco","Mozambique","Myanmar","Namibia","Nepal","Netherlands","New Zealand","Nicaragua","Niger","Nigeria","Norway","Pakistan","Panama","Paraguay","Peru","Philippines","Poland","Portugal","Romania","Russian Federation","Rwanda","Saudi Arabia","Senegal","Serbia","Sierra Leone","Singapore","Slovak Republic","Slovenia","South Africa","South Sudan","Spain","Sri Lanka","Sweden","Switzerland","Tajikistan","Tanzania","Thailand","Togo","Trinidad and Tobago","Tunisia","Turkey","Turkmenistan","Uganda","Ukraine","United Arab Emirates","United Kingdom","United States","Uruguay","Uzbekistan","Venezuela, RB","Vietnam","West Bank and Gaza","Zambia","Zimbabwe"],"locations":["AFG","ALB","DZA","ARG","ARM","AUS","AUT","AZE","BHR","BGD","BLR","BEL","BEN","BOL","BIH","BWA","BRA","BGR","BFA","KHM","CMR","CAN","CAF","TCD","CHL","CHN","COL","COD","COG","CRI","CIV","HRV","CYP","CZE","DNK","DOM","ECU","EGY","SLV","EST","ETH","FIN","FRA","GAB","GEO","DEU","GHA","GRC","GTM","GIN","HTI","HND","HKG","HUN","IND","IDN","IRN","IRQ","IRL","ISR","ITA","JPN","JOR","KAZ","KEN","KOR","XKX","KWT","KGZ","LAO","LVA","LBN","LSO","LBR","LBY","LTU","LUX","MKD","MDG","MWI","MYS","MLI","MLT","MRT","MUS","MEX","MDA","MNG","MNE","MAR","MOZ","MMR","NAM","NPL","NLD","NZL","NIC","NER","NGA","NOR","PAK","PAN","PRY","PER","PHL","POL","PRT","ROU","RUS","RWA","SAU","SEN","SRB","SLE","SGP","SVK","SVN","ZAF","SSD","ESP","LKA","SWE","CHE","TJK","TZA","THA","TGO","TTO","TUN","TUR","TKM","UGA","UKR","ARE","GBR","USA","URY","UZB","VEN","VNM","PSE","ZMB","ZWE"],"name":"","z":[2.8,27.8,24.311023622047244,46.2,26.4,90.47619047619048,88.2,34.7,85.56603773584905,6.9,75.4985754985755,95.90409590409591,12.3,28.0,44.0,31.3,59.4,69.7,17.6,8.0625,12.1,95.51345962113659,6.1,5.6,52.98076923076923,58.47808105872622,22.9,8.4,15.8,49.1,10.4,70.1,63.929618768328446,77.5,97.5,27.8,26.9,29.4,20.1,91.8,8.1,98.2,87.0,23.4,45.1,91.4,22.8,73.7,14.1,8.7,12.103174603174603,16.2,83.81330685203575,66.6,31.433333333333334,36.0,82.96812749003983,8.0,86.5,31.2,87.5,88.85572139303483,29.841897233201582,45.3,38.0,75.4,44.0,82.1,23.4,15.6,87.52495009980039,41.5,23.7,4.2,29.44111776447106,57.7,90.6,58.333333333333336,4.4,12.1,75.39840637450199,10.1,87.6370887337986,16.9,76.8,22.5,25.1,75.6,42.1,23.405088062 ...

# %% [markdown]
# Based on this, it seems the Philippines is lagging behind its neighbor countries based on debit card ownership.

# %% [markdown]
# Play around with the color scale using the following options for color_continuous_scale:
# ![Screen Shot 2022-08-27 at 9.54.38 PM.png](data:image/png;base64,...)

# %% [markdown]
# ### Bubble maps

# %%
# Build the bubble map
fig = px.scatter_geo(
    grouped_data, 
    locations="economycode", 
    color="regionwb",
    hover_name="economy", 
    size="% of population with debit card",
    projection="natural earth"
    )

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="699fc472-3da9-47ac-8d12-1244575249ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("699fc472-3da9-47ac-8d12-1244575249ad")) {                    Plotly.newPlot(                        "699fc472-3da9-47ac-8d12-1244575249ad",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>regionwb=South Asia<br>% of population with debit card=%{marker.size}<br>economycode=%{location}<extra></extra>","hovertext":["Afghanistan","Bangladesh","India","Nepal","Pakistan","Sri Lanka"],"legendgroup":"South Asia","locations":["AFG","BGD","IND","NPL","PAK","LKA"],"marker":{"color":"#636efa","size":[2.8,6.9,31.433333333333334,12.0,9.625,38.22463768115942],"sizemode":"area","sizeref":0.24675,"symbol":"circle"},"mode":"markers","name":"South Asia","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>regionwb=Europe & Central Asia (excluding high income)<br>% of population with debit card=%{marker.size}<br>economycode=%{location}<extra></extra>","hovertext":["Albania","Armenia","Azerbaijan","Belarus","Bosnia and Herzegovina","Bulgaria","Croatia","Georgia","Kazakhstan","Kosovo","Kyrgyz Republic","Macedonia, FYR","Moldova","Montenegro","Romania","Russian Federation","Serbia","Tajikistan","Turkey","Turkmenistan","Ukraine","Uzbekistan"],"legendgroup":"Europe & Central Asia (excluding high income)","locations":["ALB","ARM","AZE","BLR","BIH","BGR","HRV","GEO","KAZ","XKX","KGZ","MKD","MDA","MNE","ROU","RUS","SRB","TJK","TUR","TKM","UKR","UZB"],"marker":{"color":"#EF553B","size":[27.8,26.4,34.7,75.4985754985755,44.0,69.7,70.1,45.1,45.3,44.0,23.4,58.333333333333336,25.1,42.1,46.353646353646354,55.85,66.6,19.9,71.5,41.9,50.6,27.5],"sizemode":"area","sizeref":0.24675,"symbol":"circle"},"mode":"markers","name":"Europe & Central Asia (excluding high income)","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>regionwb=Middle East & North Africa (excluding high income)<br>% of population with debit card=%{marker.size}<br>economycode=%{location}<extra></extra>","hovertext":["Algeria","Egypt, Arab Rep.","Iran, Islamic Rep.","Iraq","Jordan","Lebanon","Libya","Morocco","Tunisia","West Bank and Gaza"],"legendgroup":"Middle East & North Africa (excluding high income)","locations":["DZA","EGY","IRN","IRQ","JOR","LBN","LBY","MAR","TUN","PSE"],"marker":{"color":"#00cc96","size":[24.311023622047244,29.4,82.96812749003983,8.0,29.841897233201582,41.5,29.44111776447106,23.40508806262231,26.973026973026972,18.9],"sizemode":"area","sizeref":0.24675,"symbol":"circle"},"mode":"markers","name":"Middle East & North Africa (excluding high income)","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>regionwb=Latin America & Caribbean (excluding high income)<br>% of population with debit card=%{marker.size}<br>economycode=%{location}<extra></extra>","hovertext":["Argentina","Bolivia","Brazil","Colombia","Costa Rica","Dominican Republic","Ecuador","El Salvador","Guatemala","Haiti","Honduras","Mexico","Nicaragua","Panama","Paraguay","Peru","Venezuela, RB"],"legendgroup":"Latin America & Caribbean (excluding high income)","locations":["ARG","BOL","BRA","COL","CRI","DOM","ECU","SLV","GTM","HTI","HND","MEX","NIC","PAN","PRY","PER","VEN"],"marker":{"color":"#ab63fa","size":[46.2,28.0,59.4,22.9,49.1,27.8,26.9,20.1,14.1,12.103174603174603,16.2,22.5,14.7,27.8,17.1,27.9,68.5],"sizemode":"area","sizeref":0.24675,"symbol":"circle"},"mode":"markers","name":"Latin America & Caribbean (excluding high income)","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>regionwb=High income: OECD<br>% of population with  ...

# %% [markdown]
# ## Sample exercise
# Replicate the choropleth map but only for countries in the "East Asia & Pacific (excluding high income)" region only.
