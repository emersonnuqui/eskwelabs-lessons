# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("wine.csv")

# %%
data.columns
# Out:
# Index(['class_label', 'class_name', 'alcohol', 'malic_acid', 'ash',
#        'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids',
#        'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue',
#        'od280', 'proline'],
#       dtype='object')

# %%
data.malic_acid.dtypes
# Out:
# dtype('float64')

# %%
label3 = data[data["class_label"] == 3]

mean = np.mean(label3['malic_acid'])

# %%
print('The average malic acid for class_label 3 is %.2f' % (mean))
# Out:
# The average malic acid for class_label 3 is 3.33

# %%
sub_df = data[data['proline'] >= 1000]
sub_df = sub_df[['alcohol', 'malic_acid', 'ash', 'color_intensity','hue']]
sub_df
# Out:
#     alcohol  malic_acid   ash  color_intensity   hue
# 0     14.23        1.71  2.43             5.64  1.04
# 1     13.20        1.78  2.14             4.38  1.05
# 2     13.16        2.36  2.67             5.68  1.03
# 3     14.37        1.95  2.50             7.80  0.86
# 5     14.20        1.76  2.45             6.75  1.05
# 6     14.39        1.87  2.45             5.25  1.02
# 7     14.06        2.15  2.61             5.05  1.06
# 8     14.83        1.64  2.17             5.20  1.08
# 9     13.86        1.35  2.27             7.22  1.01
# 10    14.10        2.16  2.30             5.75  1.25
# 11    14.12        1.48  2.32             5.00  1.17
# 12    13.75        1.73  2.41             5.60  1.15
# 13    14.75        1.73  2.39             5.40  1.25
# 14    14.38        1.87  2.38             7.50  1.20
# 15    13.63        1.81  2.70             7.30  1.28
# 16    14.30        1.92  2.72             6.20  1.07
# 17    13.83        1.57  2.62             6.60  1.13
# ...
